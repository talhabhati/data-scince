# %%
pip install matplotlib     #to install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.1-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ayyan laptop\anaconda3\envs\rstudio\lib\site-packages (from matplotlib) (3.0.4)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayyan laptop\anaconda3\envs\rstudio\lib\site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.3-cp39-cp39-win_amd64.whl (55 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\ayyan laptop\anaconda3\envs\rstudio\lib\site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayyan laptop\anaconda3\envs\rstudio\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\ayyan laptop\anaconda3\envs\rstudio\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.3 matplotlib-3.5.2 pillow-9.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline   # graph bnana k liye zarori ha
# Out:
# UsageError: unrecognized arguments: # graph bnana k liye zarori ha

# %% [markdown]
# import numpy as np

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)     #linspace 0 se 5 tak 11 values generate karega
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'c')   # x aur y k dermyan graph

# %%
plt.xlabel('time')
plt.ylabel('velocity')
# Out:
# Text(0, 0.5, 'velocity')

# %%
plt.plot(x,y,'c')
plt.xlabel('time')
plt.ylabel('velocity')
plt.title('v-t graph')    #graph ko name dega
# Out:
# Text(0.5, 1.0, 'v-t graph')

# %%
z=np.linspace(0,100,11)    # z new variable ha 11 values ka  
plt.subplot(1,2,1)    #   brackket ma (size,total graph,  graph no.)    
plt.plot(x,z,'c')
plt.subplot(1,2,2)
plt.plot(y,z,'r')

# %%
#   fig.savefig('fileame.png')     # pehla fig object ha,  png ki jaga jpg bhi extension de sakte ha 

#  fig.savefig('filename.png' , dpi=200)  # dpi ma resolutioin dekar save karwaya ha

# %%
ax.set_tiltle('title')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 ax.set_tiltle('title')
#
# NameError: name 'ax' is not defined
